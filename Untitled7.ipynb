# %%
import sys
sys.path.append(r'..//')
from ioMicro import *


save_folder =r'\\192.168.0.6\bbfishjoy4extra\MERFISH_AnalysisE1'
fov,set_ = 'Conv_zscan__040', '_D16' ################## Change 
dec = decoder_simple(save_folder,fov,set_)
dec.ncols = 3
dec.load_decoded()
apply_fine_drift(dec,plt_val=True)
#apply_flat_field(dec,tag='med_col_raw')
# Out:
# Loaded decoded: -0.6776063442230225
# 100%|██████████████████████████████████████████████████████████████████████████████████| 21/21 [00:01<00:00, 12.23it/s]
